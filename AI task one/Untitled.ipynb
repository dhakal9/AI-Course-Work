# %%
import numpy as np #nup
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression as LR
from sklearn.metrics import r2_score,mean_squared_error
from sklearn.datasets import load_boston

# %%
dataset=load_boston()

# %%
dataset.feature_names
# Out:
# array(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD',
#        'TAX', 'PTRATIO', 'B', 'LSTAT'], dtype='<U7')

# %%
dataset.DESCR
print(dataset.DESCR)
# Out:
# .. _boston_dataset:
#
# Boston house prices dataset
# ---------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 506
#
#     :Number of Attributes: 13 numeric/categorical predictive. Median Value (attribute 14) is usually the target.
#
#     :Attribute Information (in order):
#         - CRIM     per capita crime rate by town
#         - ZN       proportion of residential land zoned for lots over 25,000 sq.ft.
#         - INDUS    proportion of non-retail business acres per town
#         - CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
#         - NOX      nitric oxides concentration (parts per 10 million)
#         - RM       average number of rooms per dwelling
#         - AGE      proportion of owner-occupied units built prior to 1940
#         - DIS      weighted distances to five Boston employment centres
#         - RAD      index of accessibility to radial highways
# ...

# %%
X=dataset.data
Y=dataset.target

# %%
fig,axs=plt.subplots(13,2,figsize=(10,40))
fig.tight_layout()
plt.subplots_adjust(left=2, bottom=3, right=3, top=4)
print(dataset.feature_names)
for i in range(13):


    m,b=np.polyfit(X[:,i],Y,1)
    axs[i,0].scatter(X[:,i],Y)
    axs[i,0].plot(X[:,i],m*X[:,i]+b)
    axs[i,0].set_title(str(i)+" "+dataset.feature_names[i]+" scatter plot")
    axs[i,1].hist(X[:,i])
    axs[i,1].set_title(str(i)+" "+dataset.feature_names[i]+" histogram plot")
# Out:
# ['CRIM' 'ZN' 'INDUS' 'CHAS' 'NOX' 'RM' 'AGE' 'DIS' 'RAD' 'TAX' 'PTRATIO'
#  'B' 'LSTAT']

# %%
data_Train,data_Test,Target_Train,Target_Test=train_test_split(X,Y,random_state=1,test_size=0.1
                                                              )

# %%
model=LR()

# %%
model.fit(data_Train,Target_Train)
# Out:
# LinearRegression()

# %%
model.score(data_Test,Target_Test)
# Out:
# 0.7786386580298914

# %%
Target_pred = model.predict(data_Test)

print('Coefficients: \n', model.coef_)

print('Mean squared error: %.2f'
      % mean_squared_error(Target_Test, Target_pred))

print('Coefficient of determination: %.2f'
      % r2_score(Target_Test, Target_pred))
# Out:
# Coefficients:
#  [-1.16259926e-01  5.56061815e-02  2.42066570e-03  2.58498034e+00
#  -1.91474547e+01  3.54362973e+00 -5.86296897e-04 -1.59321860e+00
#   3.16227116e-01 -1.20965602e-02 -9.20798781e-01  8.75217941e-03
#  -5.18191990e-01]
# Mean squared error: 20.54
# Coefficient of determination: 0.78
